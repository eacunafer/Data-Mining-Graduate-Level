# %% [markdown]
# ## COMP 6315
# ## Edgar Acuna
# ### Graficas en Python usando cuatro librerias: ggplot, plotly, seaborn y bokeh (Python 2)

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from ggplot import mtcars
import bokeh

# %%
#llamando a plotnine
import plotnine

# %%
# Otra forma de llamar a plotnine
from plotnine import *

# %%
#Funcion magica para que la grafica de matplotlib salga en la pantalla
# %matplotlib inline

# %%
#Leyendo los datos
datos1=pd.read_csv("http://academic.uprm.edu/eacuna/clase97.txt",sep=" ")

# %%
datos1.head()
# Out:
#    edad sexo escuela programa creditos   gpa  familia  hestud  htv
# 0    21    f    publ     biol      119  3.60        3      35   10
# 1    18    f    priv     mbio       15  3.60        3      30   10
# 2    19    f    priv     biot       73  3.61        5       5    7
# 3    20    f    priv     mbio        *  2.38        3      14    3
# 4    21    m    publ     pmed      114  3.15        2      25   25

# %%
# Histograma de gpa usando ggplot
p=ggplot(aes(x='gpa'),data=datos1)
p+geom_histogram(binwidth=.35)
# Out:
# <ggplot: (12537720)>

# %% [markdown]
# Notar que en lugar de 5 intervalos ggplot muestra 10 intervalos

# %%
# Histograma de gpa cpn 8 intervalos usando ggplot
p=ggplot(aes(x = 'mpg'),data=mtcars) 
p=p+geom_histogram(colour = "black" , fill = "red" , bins = 8)
p
# Out:
# <ggplot: (12570239)>

# %% [markdown]
# Nuevamente notar de que a pesar que se le pide 8 intervalos, ggplot muestra 8 intervalos. La funcion parece estar con errores aun

# %%
#Histogram de gpa usando seaborn
sns.distplot(datos1['gpa'],kde=False, color="blue")

# %%
#otra vez el histograma en seaborn usando 5 intervalos
sns.distplot(datos1['gpa'],bins=5, kde=False, color="cyan")

# %%
#Histograma usando plotly
import plotly 
import plotly.graph_objs as go
plotly.offline.init_notebook_mode(connected=True)

x = datos1['gpa']
data = [go.Histogram(x=x)]

plotly.offline.iplot(data, filename='histograma en plotly')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="cd035cad-881a-4489-990a-c0173bd0b8a8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("cd035cad-881a-4489-990a-c0173bd0b8a8", [{"x": [3.6, 3.6, 3.61, 2.38, 3.15, 3.17, 2.15, 3.86, 3.19, 3.66, 3.35, 3.17, 3.23, 3.36, 2.88, 2.8, 2.5, 3.46, 2.74, 3.07, 2.2, 2.39, 3.05, 3.55, 3.03, 3.61, 2.73, 3.54], "type": "histogram"}], {}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# Comentario: Me da la impresion de que la libreria mas estable es seaborn.
# Lo unico malo es que no hace pie charts

# %%
# haciendo un segundo ejemplo con el cojunto de dato mtcars que viene dentro de pandas
mtcars.head()
# Out:
#                 name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
#Haciendo el histograma cpn seaborn
sns.distplot(mtcars['mpg'],kde=False)

# %%
#Haciendo el histograma con ggplopt
p = ggplot(aes(x='mpg'), data=mtcars)
p+geom_histogram(fill="green")
# Out:
# C:\Users\edgar2017\Anaconda2\envs\ipykernel_py2\lib\site-packages\plotnine\stats\stat_bin.py:90: UserWarning:
#
# 'stat_bin()' using 'bins = 6'. Pick better value with 'binwidth'.
# <ggplot: (17437858)>

# %%
#haciendo el histograma con Bokeh
from bokeh.charts import Histogram
from bokeh.charts import defaults, show
from bokeh.io import output_notebook

# input options
output_notebook()
hist = Histogram(datos1['gpa'], title="Histograma de GPA")

show(hist)
# Out:
# C:\Users\edgar2017\Anaconda2\envs\ipykernel_py2\lib\site-packages\bokeh\util\deprecation.py:34: BokehDeprecationWarning:
#
#
# The bokeh.charts API has moved to a separate 'bkcharts' package.
#
# This compatibility shim will remain until Bokeh 1.0 is released.
# After that, if you want to use this API you will have to install
# the bkcharts package explicitly.
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f96e4717-19aa-4429-8080-04b96711499f">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9305ed0d-c52a-47f9-84f8-581e4d6311b0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9305ed0d-c52a-47f9-84f8-581e4d6311b0");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9305ed0d-c52a-47f9-84f8-581e4d6311b0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9305ed0d-c52a-47f9-84f8-581e4d6311b0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e9f502d1-7559-4875-a10e-2cca66828917":{"roots":{"references":[{"attributes":{"plot":null,"text":"Histograma de GPA"},"id":"6dd499ea-4c0c-410d-9ec3-ccf8ff01daf5","type":"Title"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(3.432500, 3.860000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[9.0],"label":["(3.432500, 3.860000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.42749999999999977],"x":["3.64625"],"y":[4.5]}},"id":"725ebf84-a25b-4583-b2c3-23d7ce92bb61","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5e0897ed-6227-4f77-9419-c9c14981c1e0","type":"Rect"},{"attributes":{"callback":null,"end":4.01025,"start":1.9997500000000004},"id":"1190f2a6-559c-45eb-bf98-57d0d51533cf","type":"Range1d"},{"attributes":{"data_source":{"id":"725ebf84-a25b-4583-b2c3-23d7ce92bb61","type":"ColumnDataSource"},"glyph":{"id":"70b17097-4d7a-4ee4-b74b-f5fef9c9e4b0","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"848af197-4c7d-4c0e-9cee-c8adc75d2e88","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"cc977f85-622d-4540-8c23-979493c5680c","subtype":"Chart","type":"Plot"},"ticker":{"id":"644d1a18-9a16-4175-84f4-3adf3bc7375a","type":"BasicTicker"}},"id":"86b4fd49-e5a1-4b12-9b90-b5c0f67443a6","type":"Grid"},{"attributes":{},"id":"10c5b4c3-c986-4a32-85e1-575606ac080e","type":"BasicTicker"},{"attributes":{"overlay":{"id":"906d3799-83c7-44c9-a8e7-ed986d9a6333","type":"BoxAnnotation"},"plot":{"id":"cc977f85-622d-4540-8c23-979493c5680c","subtype":"Chart","type":"Plot"}},"id":"159cdee5-3cb5-43f2-afa2-5cb8ae04ecde","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"cc977f85-622d-4540-8c23-979493c5680c","subtype":"Chart","type":"Plot"}},"id":"e164091a-b095-4f26-8987-ac0cd12495e4","type":"SaveTool"},{"attributes":{"callback":null,"end":11.0},"id":"d6bb94f4-b40e-433d-a12e-6192d3738019","type":"Range1d"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"70b17097-4d7a-4ee4-b74b-f5fef9c9e4b0","type":"Rect"},{"attributes":{},"id":"644d1a18-9a16-4175-84f4-3adf3bc7375a","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(2.577500, 3.005000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[4.0],"label":["(2.577500, 3.005000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.4275000000000002],"x":["2.79125"],"y":[2.0]}},"id":"548bc6c0-efc6-4e3b-903e-02159b06bd79","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"cc977f85-622d-4540-8c23-979493c5680c","subtype":"Chart","type":"Plot"}},"id":"5c848daa-881b-4fd7-b8df-598ea97f03f6","type":"ResetTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"026f21c1-560d-4849-9764-c19c4cb2710e","type":"Rect"},{"attributes":{},"id":"fef9744d-cb5d-4cac-9677-1eefd17f648e","type":"LinearScale"},{"attributes":{"below":[{"id":"63dee982-55dc-4fbf-9c78-56708a2810f2","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"2d0f316b-7953-454c-8131-21311ac7c3e0","type":"LinearAxis"}],"renderers":[{"id":"906d3799-83c7-44c9-a8e7-ed986d9a6333","type":"BoxAnnotation"},{"id":"82419a68-3af9-440f-af32-d14163ad843d","type":"GlyphRenderer"},{"id":"50fff671-1500-4584-8ba2-95d21da56b1f","type":"GlyphRenderer"},{"id":"0774738c-a74c-4cd3-a069-4ea9527d ...

# %%
# Scatterplot 2D usando matplotlib
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
import random


fig = pyplot.figure()
ax = Axes3D(fig)

sequence_containing_x_vals = list(range(0, 100))
sequence_containing_y_vals = list(range(0, 100))
sequence_containing_z_vals = list(range(0, 100))

random.shuffle(sequence_containing_x_vals)
random.shuffle(sequence_containing_y_vals)
random.shuffle(sequence_containing_z_vals)

ax.scatter(sequence_containing_x_vals, sequence_containing_y_vals, sequence_containing_z_vals)
pyplot.show()

# %%
import plotly as py
import plotly.graph_objs as go

py.offline.init_notebook_mode(connected=True)
import numpy as np

x, y, z = np.random.multivariate_normal(np.array([0,0,0]), np.eye(3), 200).transpose()
trace1 = go.Scatter3d(
    x=x,
    y=y,
    z=z,
    mode='markers',
    marker=dict(
        size=12,
        line=dict(
            color='rgba(217, 217, 217, 0.14)',
            width=0.5
        ),
        opacity=0.8
    )
)

x2, y2, z2 = np.random.multivariate_normal(np.array([0,0,0]), np.eye(3), 200).transpose()
trace2 = go.Scatter3d(
    x=x2,
    y=y2,
    z=z2,
    mode='markers',
    marker=dict(
        color='rgb(127, 127, 127)',
        size=12,
        symbol='circle',
        line=dict(
            color='rgb(204, 204, 204)',
            width=1
        ),
        opacity=0.9
    )
)
data = [trace1, trace2]
layout = go.Layout(
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0
    )
)
fig = go.Figure(data=data, layout=layout)
py.offline.iplot(fig, filename='simple-3d-scatter')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="ea8f605f-3058-4d5f-b02c-efcaa4089bc7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ea8f605f-3058-4d5f-b02c-efcaa4089bc7", [{"marker": {"opacity": 0.8, "line": {"color": "rgba(217, 217, 217, 0.14)", "width": 0.5}, "size": 12}, "mode": "markers", "y": [-0.14713281682390705, -0.45716108671638944, -0.8413178057922328, 0.7433159889567991, -1.6684511355448486, 0.12182035693222454, 1.37850676229116, 1.9512993924187991, -0.5252181183644173, -0.680167574772669, 0.9257885405455023, -0.6947251719344532, 0.8254051561196025, -0.791263576471904, 2.6287614431729773, 0.5192654015897827, -1.0375732693911852, -0.12787524458475932, 0.295307390789675, 0.4091535914337602, -0.3836700390694528, 0.7837425931015767, 0.47348824659305594, -0.12228485661156453, -0.4469550147923291, 0.457943519212398, 1.373176827774509, 0.2552758413041161, 0.3262552152728078, 0